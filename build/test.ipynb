# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# %matplotlib inline

# %%
img = mpimg.imread("img_test/box_in_scene.png")
imgplot = plt.imshow(img,cmap=plt.cm.gray)

# %%
import libsurfgpu

# %%
keypoints = libsurfgpu.compute("img_test/box_in_scene.png")

# %%
# size of keypoints is n_features*2
keypoints = np.array(keypoints).reshape(np.shape(keypoints)[0]//2,2)

# %%
plt.plot(keypoints[:,0],keypoints[:,1],".")
imgplot = plt.imshow(img,cmap=plt.cm.gray)
